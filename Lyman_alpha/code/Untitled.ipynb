# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#this is a competition between us
#I want to define V = mgz
#so that at V  =0, z = 0
zi = np.arange(0,10,0.01)
def potential_jebraan(zj):
    return m*g*zj
m = 4 #kg,mass of object
g = 9.8 #ms^-2
plt.plot(z , potential_jebraan(z))
#see at z = 0, V= 0

# %%
#this is a competition between us
#you want to define V = mgz +k
#so that at V  =0, z = 0
k = 50 #yeh tu choose kar, teri marzi
zm = np.arange(0,10,0.01)
def potential_princess(zd):
    return m*g*zd + k 
m = 4 #kg,mass of object
g = 9.8 #ms^-2
plt.plot(zm , potential_princess(zm))
#see at z = 3, V is not zero but some constant
